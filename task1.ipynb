# %%
import pandas as pd;
import numpy as np;
import math;

# %%
#df1 = pd.read_csv("2020_US_weekly_symptoms_dataset.csv");
#df2 = pd.read_csv("aggregated_cc_by.csv");
df3 = pd.read_csv("mobility_report/2020_US_Region_Mobility_Report.csv");

# %%
df1_nan_cols = df1.isnull().sum().to_frame()
df1_nan_cols.reset_index(level=0, inplace=True)
df1_nan_cols.columns=["features", "num_nan"]
df1_nan_cols_copy = df1_nan_cols.copy

# %%
df1_nan_cols = df1_nan_cols.sort_values(by="num_nan", ascending=False)
df1_nan_cols
# Out:
#                     features  num_nan
# 429     symptom:pancreatitis      608
# 239        symptom:Knee Pain      608
# 249       symptom:Lymphedema      608
# 248  symptom:Low-grade fever      608
# 247    symptom:Low back pain      608
# ..                       ...      ...
# 7                       date        0
# 4          sub_region_1_code        0
# 3               sub_region_1        0
# 2             country_region        0
# 0     open_covid_region_code        0
#
# [430 rows x 2 columns]

# %%
df1_nan_cols = df1_nan_cols.loc[df1_nan_cols['num_nan'] == 608]
df1_nan_cols
# Out:
#                           features  num_nan
# 429           symptom:pancreatitis      608
# 239              symptom:Knee Pain      608
# 249             symptom:Lymphedema      608
# 248        symptom:Low-grade fever      608
# 247          symptom:Low back pain      608
# ..                             ...      ...
# 132         symptom:Encephalopathy      608
# 113           symptom:Desquamation      608
# 118              symptom:Dizziness      608
# 116  symptom:Diabetic ketoacidosis      608
# 122           symptom:Dysmenorrhea      608
#
# [303 rows x 2 columns]

# %%
df1 = df1.dropna(how='all', axis=1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-32df9906a6b4> in <module>
# ----> 1 df1 = df1.dropna(how='all', axis=1)
#
# NameError: name 'df1' is not defined

# %%
us_daily = df2.loc[df2["region_name"] == "United States of America"]

# %%
#us_daily = us_daily.dropna(how='all', axis=1)

# %%
us_daily = us_daily.replace(np.nan,0)

# %%
us_daily['date'] = us_daily['date'].astype('datetime64[ns]')

# %%
weekly_data = us_daily.groupby("open_covid_region_code").resample('W-Mon', label='right', closed = 'right', on='date').sum().reset_index().sort_values(by='date')

# %%
us_daily = weekly_data

# %%
df1.to_csv("2020_US_weekly_symptoms_dataset.csv")

# %%
us_daily.to_csv("us_daily_ds2.csv")

# %%
df3[ df3['sub_region_1'] == np.nan ]
# Out:
# Empty DataFrame
# Columns: [country_region_code, country_region, sub_region_1, sub_region_2, metro_area, iso_3166_2_code, census_fips_code, date, retail_and_recreation_percent_change_from_baseline, grocery_and_pharmacy_percent_change_from_baseline, parks_percent_change_from_baseline, transit_stations_percent_change_from_baseline, workplaces_percent_change_from_baseline, residential_percent_change_from_baseline]
# Index: []

# %%
df3 = df3.drop(df3.head(2).index)
df3 = df3.reset_index(drop=True)

# %%
d = df3.drop(df3[pd.isna(df3["sub_region_2"]) == False].index)
d
# Out:
#        country_region_code country_region sub_region_1 sub_region_2  \
# 0                       US  United States          NaN          NaN
# 1                       US  United States          NaN          NaN
# 2                       US  United States          NaN          NaN
# 3                       US  United States          NaN          NaN
# 4                       US  United States          NaN          NaN
# ...                    ...            ...          ...          ...
# 567743                  US  United States      Wyoming          NaN
# 567744                  US  United States      Wyoming          NaN
# 567745                  US  United States      Wyoming          NaN
# 567746                  US  United States      Wyoming          NaN
# 567747                  US  United States      Wyoming          NaN
#
#         metro_area iso_3166_2_code  census_fips_code        date  \
# 0              NaN             NaN               NaN  2020-02-17
# 1              NaN             NaN               NaN  2020-02-18
# 2              NaN             NaN               NaN  2020-02-19
# 3              NaN             NaN               NaN  2020-02-20
# 4              NaN             NaN               NaN  2020-02-21
# ...            ...             ...               ...         ...
# 567743         NaN           US-WY               NaN  2020-09-26
# 567744         NaN           US-WY               NaN  2020-09-27
# 567745         NaN           US-WY               NaN  2020-09-28
# 567746         NaN           US-WY               NaN  2020-09-29
# 567747         NaN           US-WY               NaN  2020-09-30
#
#         retail_and_recreation_percent_change_from_baseline  \
# 0                                                     6.0
# 1                                                     0.0
# 2                                                     2.0
# 3                                                     1.0
# 4                                                     2.0
# ...                                                   ...
# 567743                                               -3.0
# 567744                                                1.0
# 567745                                                2.0
# 567746                                                2.0
# 567747                                                2.0
#
#         grocery_and_pharmacy_percent_change_from_baseline  \
# 0                                                     0.0
# 1                                                    -1.0
# 2                                                     0.0
# 3                                                     0.0
# 4                                                    -2.0
# ...                                                   ...
# 567743                                               13.0
# 567744                                                9.0
# 567745                                               13.0
# 567746                                               12.0
# 567747                                               14.0
#
#         parks_percent_change_from_baseline  \
# 0                                     28.0
# 1                                      6.0
# 2                                      8.0
# 3                                      4.0
# 4                                      4.0
# ...                                    ...
# 567743                               169.0
# 567744                               131.0
# 567745                               165.0
# 567746                               163.0
# 567747                               158.0
#
#         transit_stations_percent_change_from_baseline  \
# 0                                                -9.0
# 1                                                 1.0
# 2                                                 1.0
# 3                                                 0.0
# 4                                                 1.0
# ...                                               ...
# 567743                                           33.0
# 567744                                           28.0
# 567745                                           26.0
# 567746                                           24.0
# 567747                                           22.0
#
#         workplaces_percent_change_from_baseline  \
# 0                                         -24.0
# 1                                           0.0
# 2                                           1.0
# 3                                           0.0
# 4                                           0.0
# ...                                         ...
# 567743                                     -8.0
# 567744                                    -10.0
# 567745                                    -17.0
# 567746                                    -16.0
# 567747                                    -19.0
#
#         residential_percent_change_from_baseline
# 0                                            5.0
# 1                                            1.0
# 2                                            0.0
# 3                                            1.0
# 4                                            0.0
# ...                                          ...
# 567743                                       1.0
# 567744                                       1.0
# 567745                                       2.0
# 567746                                       2.0
# 567747                                       1.0
#
# [11906 rows x 14 columns]

# %%
d['date'] = d['date'].astype('datetime64[ns]')
d = d.groupby(["country_region","sub_region_1"]).resample('W-Mon', on='date').sum().reset_index().sort_values(by='date')

# %%
d
# Out:
#      country_region    sub_region_1       date  metro_area  census_fips_code  \
# 0     United States         Alabama 2020-02-17         0.0               0.0
# 408   United States           Idaho 2020-02-17         0.0               0.0
# 1326  United States    Rhode Island 2020-02-17         0.0               0.0
# 374   United States          Hawaii 2020-02-17         0.0               0.0
# 1360  United States  South Carolina 2020-02-17         0.0               0.0
# ...             ...             ...        ...         ...               ...
# 1325  United States    Pennsylvania 2020-10-05         0.0               0.0
# 1699  United States       Wisconsin 2020-10-05         0.0               0.0
# 373   United States         Georgia 2020-10-05         0.0               0.0
# 135   United States        Arkansas 2020-10-05         0.0               0.0
# 1733  United States         Wyoming 2020-10-05         0.0               0.0
#
#       retail_and_recreation_percent_change_from_baseline  \
# 0                                                   8.0
# 408                                                24.0
# 1326                                               23.0
# 374                                                11.0
# 1360                                               16.0
# ...                                                 ...
# 1325                                              -24.0
# 1699                                              -29.0
# 373                                               -25.0
# 135                                               -10.0
# 1733                                                4.0
#
#       grocery_and_pharmacy_percent_change_from_baseline  \
# 0                                                   0.0
# 408                                                10.0
# 1326                                              -11.0
# 374                                                 1.0
# 1360                                                4.0
# ...                                                 ...
# 1325                                               -7.0
# 1699                                               -2.0
# 373                                               -11.0
# 135                                                -2.0
# 1733                                               26.0
#
#       parks_percent_change_from_baseline  \
# 0                                   49.0
# 408                                 65.0
# 1326                               118.0
# 374                                 48.0
# 1360                                67.0
# ...                                  ...
# 1325                                63.0
# 1699                               163.0
# 373                                 10.0
# 135                                151.0
# 1733                               321.0
#
#       transit_stations_percent_change_from_baseline  \
# 0                                              17.0
# 408                                             0.0
# 1326                                           -4.0
# 374                                             6.0
# 1360                                           24.0
# ...                                             ...
# 1325                                          -70.0
# 1699                                          -35.0
# 373                                           -65.0
# 135                                            -7.0
# 1733                                           46.0
#
#       workplaces_percent_change_from_baseline  \
# 0                                       -16.0
# 408                                     -27.0
# 1326                                    -31.0
# 374                                     -49.0
# 1360                                    -16.0
# ...                                       ...
# 1325                                    -63.0
# 1699                                    -54.0
# 373                                     -62.0
# 135                                     -44.0
# 1733                                    -35.0
#
#       residential_percent_change_from_baseline
# 0                                          4.0
# 408                                        3.0
# 1326                                       6.0
# 374                                       10.0
# 1360                                       2.0
# ...                                        ...
# 1325                                      17.0
# 1699                                      18.0
# 373                                       17.0
# 135                                        8.0
# 1733                                       3.0
#
# [1734 rows x 11 columns]

# %%
d = d.sort_index()

# %%
d.to_csv("mobility_report/us_mobility_weekly.csv")

# %%
d
# Out:
#      country_region sub_region_1       date  metro_area  census_fips_code  \
# 0     United States      Alabama 2020-02-17         0.0               0.0
# 1     United States      Alabama 2020-02-24         0.0               0.0
# 2     United States      Alabama 2020-03-02         0.0               0.0
# 3     United States      Alabama 2020-03-09         0.0               0.0
# 4     United States      Alabama 2020-03-16         0.0               0.0
# ...             ...          ...        ...         ...               ...
# 1729  United States      Wyoming 2020-09-07         0.0               0.0
# 1730  United States      Wyoming 2020-09-14         0.0               0.0
# 1731  United States      Wyoming 2020-09-21         0.0               0.0
# 1732  United States      Wyoming 2020-09-28         0.0               0.0
# 1733  United States      Wyoming 2020-10-05         0.0               0.0
#
#       retail_and_recreation_percent_change_from_baseline  \
# 0                                                   8.0
# 1                                                   2.0
# 2                                                  86.0
# 3                                                  77.0
# 4                                                  28.0
# ...                                                 ...
# 1729                                               64.0
# 1730                                               16.0
# 1731                                               35.0
# 1732                                               -1.0
# 1733                                                4.0
#
#       grocery_and_pharmacy_percent_change_from_baseline  \
# 0                                                   0.0
# 1                                                  -5.0
# 2                                                  44.0
# 3                                                  49.0
# 4                                                 138.0
# ...                                                 ...
# 1729                                              180.0
# 1730                                              103.0
# 1731                                              116.0
# 1732                                               86.0
# 1733                                               26.0
#
#       parks_percent_change_from_baseline  \
# 0                                   49.0
# 1                                   39.0
# 2                                  174.0
# 3                                  217.0
# 4                                  210.0
# ...                                  ...
# 1729                                 0.0
# 1730                               982.0
# 1731                              1652.0
# 1732                              1222.0
# 1733                               321.0
#
#       transit_stations_percent_change_from_baseline  \
# 0                                              17.0
# 1                                              42.0
# 2                                              83.0
# 3                                              68.0
# 4                                              46.0
# ...                                             ...
# 1729                                          239.0
# 1730                                          169.0
# 1731                                          245.0
# 1732                                          199.0
# 1733                                           46.0
#
#       workplaces_percent_change_from_baseline  \
# 0                                       -16.0
# 1                                         9.0
# 2                                        13.0
# 3                                        18.0
# 4                                        -9.0
# ...                                       ...
# 1729                                   -185.0
# 1730                                   -131.0
# 1731                                   -113.0
# 1732                                   -105.0
# 1733                                    -35.0
#
#       residential_percent_change_from_baseline
# 0                                          4.0
# 1                                          6.0
# 2                                         -8.0
# 3                                         -4.0
# 4                                          4.0
# ...                                        ...
# 1729                                      13.0
# 1730                                       8.0
# 1731                                       3.0
# 1732                                      13.0
# 1733                                       3.0
#
# [1734 rows x 11 columns]
